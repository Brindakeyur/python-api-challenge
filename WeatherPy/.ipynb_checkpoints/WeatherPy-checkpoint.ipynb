# %% [markdown]
# # WeatherPy
#
# ---
#
# ## Starter Code to Generate Random Geographic Coordinates and a List of Cities

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
from scipy.stats import linregress
from pprint import pprint

# Impor the OpenWeatherMap API key
from api_keys import weather_api_key

# Import citipy to determine the cities based on latitude and longitude
from citipy import citipy

# %% [markdown]
# ### Generate the Cities List by Using the `citipy` Library

# %%
# Empty list for holding the latitude and longitude combinations
lat_lngs = []

# Empty list for holding the cities names
cities = []

# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# Create a set of random lat and lng combinations
lats = np.random.uniform(lat_range[0], lat_range[1], size=1500)
lngs = np.random.uniform(lng_range[0], lng_range[1], size=1500)
lat_lngs = zip(lats, lngs)

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lngs:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
print(f"Number of cities in the list: {len(cities)}")
# Out:
# Number of cities in the list: 651

# %% [markdown]
# ---

# %% [markdown]
# ## Requirement 1: Create Plots to Showcase the Relationship Between Weather Variables and Latitude
#
# ### Use the OpenWeatherMap API to retrieve weather data from the cities list generated in the started code

# %%
# Set the API base URL
#url = f"http://api.openweathermap.org/data/2.5/weather?appid={weather_api_key}&units=metric&q="
url = "http://api.openweathermap.org/data/2.5/weather?"

# Define an empty list to fetch the weather data for each city
city_data = []

# Print to logger
print("Beginning Data Retrieval     ")
print("-----------------------------")

# Create counters
record_count = 1
set_count = 1

# Loop through all the cities in our list to fetch weather data
for i, city in enumerate(cities):
    # Group cities in sets of 50 for logging purposes
    if (i % 50 == 0 and i >= 50):
        set_count += 1
        record_count = 0

    # Create endpoint URL with each city
    city_url = url + "appid=" + weather_api_key + "&units=metric&q=" + city
    
    # Log the url, record, and set numbers
    print("Processing Record %s of Set %s | %s" % (record_count, set_count, city))

    # Add 1 to the record count
    record_count += 1
    
    # Run an API request for each of the cities
    try:
        # Parse the JSON and retrieve data
        city_r = requests.get(city_url).json()

        # Parse out latitude, longitude, max temp, humidity, cloudiness, wind speed, country, and date
        city_lat = city_r["coord"]["lat"]
        city_lng = city_r["coord"]["lon"]
        city_max_temp = city_r["main"]["temp_max"]
        city_humidity = city_r["main"]["humidity"]
        city_clouds = city_r["clouds"]["all"]
        city_wind = city_r["wind"]["speed"]
        city_country = city_r["sys"]["country"]
        city_date = city_r["dt"]

        # Append the City information into city_data list
        city_data.append({
            "City": city, 
            "Lat": city_lat, 
            "Lng": city_lng, 
            "Max Temp": city_max_temp,
            "Humidity": city_humidity,
            "Cloudiness": city_clouds,
            "Wind Speed": city_wind,
            "Country": city_country,
            "Date": city_date
        })

    # If an error is experienced, skip the city
    except:
        print("City not found. Skipping...")
        pass
              
# Indicate that Data Loading is complete 
print("-----------------------------")
print("Data Retrieval Complete      ")
print("-----------------------------")
# Out:
# Beginning Data Retrieval
# -----------------------------
# Processing Record 1 of Set 1 | ushuaia
# Processing Record 2 of Set 1 | anchorage
# Processing Record 3 of Set 1 | kapaa
# Processing Record 4 of Set 1 | souillac
# Processing Record 5 of Set 1 | nikolskoye
# Processing Record 6 of Set 1 | hermanus
# Processing Record 7 of Set 1 | yellowknife
# Processing Record 8 of Set 1 | darhan
# Processing Record 9 of Set 1 | hilo
# Processing Record 10 of Set 1 | goderich
# Processing Record 11 of Set 1 | marawi
# Processing Record 12 of Set 1 | arraial do cabo
# Processing Record 13 of Set 1 | black forest
# Processing Record 14 of Set 1 | ladushkin
# Processing Record 15 of Set 1 | provideniya
# Processing Record 16 of Set 1 | atuona
# Processing Record 17 of Set 1 | oktyabrskoye
# Processing Record 18 of Set 1 | howard springs
# Processing Record 19 of Set 1 | broome
# Processing Record 20 of Set 1 | rikitea
# Processing Record 21 of Set 1 | chokurdakh
# Processing Record 22 of Set 1 | georgetown
# Processing Record 23 of Set 1 | san patricio
# Processing Record 24 of Set 1 | yar-sale
# Processing Record 25 of Set 1 | illoqqortoormiut
# City not found. Skipping...
# Processing Record 26 of Set 1 | bredasdorp
# Processing Record 27 of Set 1 | nguiu
# City not found. Skipping...
# Processing Record 28 of Set 1 | albany
# Processing Record 29 of Set 1 | xichang
# Processing Record 30 of Set 1 | grand gaube
# Processing Record 31 of Set 1 | karkaralinsk
# City not found. Skipping...
# Processing Record 32 of Set 1 | leningradskiy
# Processing Record 33 of Set 1 | lorengau
# Processing Record 34 of Set 1 | tuktoyaktuk
# Processing Record 35 of Set 1 | mataura
# Processing Record 36 of Set 1 | shache
# Processing Record 37 of Set 1 | puerto ayora
# Processing Record 38 of Set 1 | williams lake
# Processing Record 39 of Set 1 | ulaangom
# Processing Record 40 of Set 1 | custodia
# Processing Record 41 of Set 1 | tayoltita
# Processing Record 42 of Set 1 | kruisfontein
# Processing Record 43 of Set 1 | punta arenas
# Processing Record 44 of Set 1 | deputatskiy
# Processing Record 45 of Set 1 | sao filipe
# Processing Record 46 of Set 1 | saint-philippe
# Processing Record 47 of Set 1 | verkhnevilyuysk
# Processing Record 48 of Set 1 | hobart
# Processing Record 49 of Set 1 | bone
# Processing Record 50 of Set 1 | bengkulu
# Processing Record 0 of Set 2 | acapulco
# Processing Record 1 of Set 2 | asfi
# Processing Record 2 of Set 2 | amderma
# City not found. Skipping...
# Processing Record 3 of Set 2 | kalmunai
# Processing Record 4 of Set 2 | busselton
# Processing Record 5 of Set 2 | lompoc
# Processing Record 6 of Set 2 | bow island
# Processing Record 7 of Set 2 | atar
# Processing Record 8 of Set 2 | portland
# Processing Record 9 of Set 2 | jamestown
# Processing Record 10 of Set 2 | kahului
# Processing Record 11 of Set 2 | qaanaaq
# Processing Record 12 of Set 2 | cape town
# Processing Record 13 of Set 2 | port-gentil
# Processing Record 14 of Set 2 | durazno
# Processing Record 15 of Set 2 | rafaela
# Processing Record 16 of Set 2 | tsihombe
# City not found. Skipping...
# Processing Record 17 of Set 2 | ayr
# Processing Record 18 of Set 2 | east london
# Processing Record 19 of Set 2 | cherskiy
# Processing Record 20 of Set 2 | iiyama
# Processing Record 21 of Set 2 | chupa
# Processing Record 22 of Set 2 | xining
# Processing Record 23 of Set 2 | soplaviento
# Processing Record 24 of Set 2 | nouadhibou
# Processing Record 25 of Set 2 | zeya
# Processing Record 26 of Set 2 | barrow
# Processing Record 27 of Set 2 | cairns
# Processing Record 28 of Set 2 | laredo
# Processing Record 29 of Set 2 | brindisi
# Processing Record 30 of Set 2 | kaeo
# Processing Record 31 of Set 2 | beringovskiy
# Processing Record 32 of Set 2 | dwarka
# Processing Record 33 of Set 2 | conselheiro pena
# Processing Record 34 of Set 2 | chaman
# Processing Record 35 of Set 2 | rtishchevo
# Processing Record 36 of Set 2 | hasaki
# Processing Record 37 of Set 2 | kampot
# Processing Record 38 of Set 2 | kuryk
# Processing Record 39 of Set 2 | kinlochleven
# Processing Record 40 of Set 2 | tiksi
# Processing Record 41 of Set 2 | labutta
# City not found. Skipping...
# Processing Record 42 of Set 2 | jalu
# Processing Record 43 of Set 2 | college
# Processing Record 44 of Set 2 | whitehorse
# Processing Record 45 of Set 2 | nanortalik
# Processing Record 46 of Set 2 | lebu
# Processing Record 47 of Set 2 | lavrentiya
# Processing Record 48 of Set 2 | valverde del camino
# Processing Record 49 of Set 2 | hengyang
# Processing Record 0 of Set 3 | mende
# Processing Record 1 of Set 3 | butaritari
# Processing Record 2 of Set 3 | kenora
# Processing Record 3 of Set 3 | taolanaro
# City not found. Skipping...
# Processing Record 4 of Set 3 | saint john
# Processing Record 5 of Set 3 | new norfolk
# Processing Record 6 of Set 3 | urdzhar
# City not found. Skipping...
# Processing Record 7 of Set 3 | batagay
# Processing Record 8 of Set 3 | inuvik
# Processing Record 9 of Set 3 | vanavara
# Processing Record 10 of Set 3 | lasa
# Processing Record 11 of Set 3 | bolungarvik
# City not found. Skipping...
# Processing Record 12 of Set 3 | uporovo
# Processing Record 13 of Set 3 | chuy
# Processing Record 14 of Set 3 | mao
# Processing Record 15 of Set 3 | shakawe
# Processing Record 16 of Set 3 | shitanjing
# Processing Record 17 of Set 3 | fukue
# Processing Record 18 of Set 3 | ust-kuyga
# Processing Record 19 of Set 3 | mar del plata
# Processing Record 20 of Set 3 | herouville-saint-clair
# Processing Record 21 of Set 3 | zanjan
# Processing Record 22 of Set 3 | isangel
# Processing Record 23 of Set 3 | krasnyye chetai
# Processing Record 24 of Set 3 | sentyabrskiy
# City not found. Skipping...
# Processing Record 25 of Set 3 | khatanga
# Processing Record 26 of Set 3 | kodiak
# Processing Record 27 of Set 3 | san cristobal
# Processing Record 28 of Set 3 | amahai
# Processing Record 29 of Set 3 | luanda
# Processing Record 30 of Set 3 | norman wells
# Processing Record 31 of Set 3 | bundaberg
# Processing Record 32 of Set 3 | strezhevoy
# Processing Record 33 of Set 3 | najran
# Processing Record 34 of Set 3 | saldanha
# Processing Record 35 of Set 3 | sao joao da barra
# Processing Record 36 of Set 3 | umm lajj
# Processing Record 37 of Set 3 | bam
# Processing Record 38 of Set 3 | grand river south east
# City not found. Skipping...
# Processing Record 39 of Set 3 | cockburn harbour
# City not found. Skipping...
# Processing Record 40 of Set 3 | pevek
# Processing Record 41 of Set 3 | akniste
# Processing Record 42 of Set 3 | puerto carreno
# Processing Record 43 of Set 3 | taburi
# City not found. Skipping...
# Processing Record 44 of Set 3 | touros
# Processing Record 45 of Set 3 | ponta do sol
# Processing Record 46 of Set 3 | port elizabeth
# Processing Record 47 of Set 3 | englehart
# Processing Record 48 of Set 3 | hithadhoo
# Processing Record 49 of Set 3 | arinos
# Processing Record 0 of Set 4 | avarua
# Processing Record 1 of Set 4 | emerald
# Processing Record 2 of Set 4 | gap
# Processing Record 3 of Set 4 | dolbeau
# City not found. Skipping...
# Processing Record 4 of Set 4 | salalah
# Processing Record 5 of Set 4 | airai
# Processing Record 6 of Set 4 | bambous virieux
# Processing Record 7 of Set 4 | clyde river
# Processing Record 8 of Set 4 | douglas
# Processing Record 9 of Set 4 | derzhavinsk
# Processing Record 10 of Set 4 | victoria
# Processing Record 11 of Set 4 | castro
# Processing Record 12 of Set 4 | mangan
# Processing Record 13 of Set 4 | sarkand
# Processing Record 14 of Set 4 | nizhneyansk
# City not found. Skipping...
# Processing Record 15 of Set 4 | coquimbo
# Processing Record 16 of Set 4 | santa cruz cabralia
# Processing Record 17 of Set 4 | cidreira
# Processing Record 18 of Set 4 | abong mbang
# Processing Record 19 of Set 4 | jiquipilas
# Processing Record 20 of Set 4 | carnarvon
# Processing Record 21 of Set 4 | erie
# Processing Record 22 of Set 4 | bluff
# Processing Record 23 of Set 4 | lokosovo
# Processing Record 24 of Set 4 | poyarkovo
# Processing Record 25 of Set 4 | yulara
# Processing Record 26 of Set 4 | attawapiskat
# City not found. Skipping...
# Processing Record 27 of Set 4 | donskoye
# Processing Record 28 of Set 4 | shenjiamen
# Processing Record 29 of Set 4 | buala
# Processing Record 30 of Set 4 | iskateley
# Processing Record 31 of Set 4 | rungata
# City not found. Skipping...
# Processing Record 32 of Set 4 | saint-nazaire
# Processing Record 33 of Set 4 | guadalupe y calvo
# Processing Record 34 of Set 4 | aklavik
# Processing Record 35 of Set 4 | thompson
# Processing Record 36 of Set 4 | bonavista
# Processing Record 37 of Set 4 | belushya guba
# City not found. Skipping...
# Processing Record 38 of Set 4 | torbay
# Processing Record 39 of Set 4 | vydrino
# Processing Record 40 of Set 4 | syedove
# Processing Record 41 of Set 4 | a
# City not found. Skipping...
# Processing Record 42 of Set 4 | malatya
# Processing Record 43 of Set 4 | suslonger
# Processing Record 44 of Set 4 | ribeira grande
# Processing Record 45 of Set 4 | tigre
# Processing Record 46 of Set 4 | sault sainte marie
# Processing Record 47 of Set 4 | mormugao
# Processing Record 48 of Set 4 | tautira
# Processing Record 49 of Set 4 | axim
# Processing Record 0 of Set 5 | fomboni
# Processing Record 1 of Set 5 | koslan
# Processing Record 2 of Set 5 | kamaishi
# Processing Record 3 of Set 5 | manbij
# Processing Record 4 of Set 5 | twante
# Processing Record 5 of Set 5 | bay saint louis
# Processing Record 6 of Set 5 | nome
# Processing Record 7 of Set 5 | espanola
# Processing Record 8 of Set 5 | port alfred
# Processing Record 9 of Set 5 | bollnas
# Processing Record 10 of Set 5 | houma
# Processing Record 11 of Set 5 | adrar
# Processing Record 12 of Set 5 | ilulissat
# Processing Record 13 of Set 5 | luderitz
# Processing Record 14 of Set 5 | zirandaro
# Processing Record 15 of Set 5 | henties bay
# Processing Record 16 of Set 5 | peniche
# Processing Record 17 of Set 5 | toktogul
# Processing Record 18 of Set 5 | maragogi
# Processing Record 19 of Set 5 | evensk
# Processing Record 20 of Set 5 | adwa
# Processing Record 21 of Set 5 | sabha
# Processing Record 22 of Set 5 | inzer
# Processing Record 23 of Set 5 | manokwari
# Processing Record 24 of Set 5 | kayes
# Processing Record 25 of Set 5 | roald
# Processing Record 26 of Set 5 | hay river
# Processing Record 27 of Set 5 | vostok
# Processing Record 28 of Set 5 | belle fourche
# Processing Record 29 of Set 5 | kazalinsk
# City not found. Skipping...
# Processing Record 30 of Set 5 | port blair
# Processing Record 31 of Set 5 | caucasia
# Processing Record 32 of Set 5 | uige
# Processing Record 33 of Set 5 | buraydah
# Processing Record 34 of Set 5 | thinadhoo
# Processing Record 35 of Set 5 | bandarbeyla
# Processing Record 36 of Set 5 | hualmay
# Processing Record 37 of Set 5 | ugoofaaru
# Processing Record 38 of Set 5 | dom pedrito
# Processing Record 39 of Set 5 | alofi
# Processing Record 40 of Set 5 | karratha
# Processing Record 41 of Set 5 | encruzilhada
# Processing Record 42 of Set 5 | hefei
# Processing Record 43 of Set 5 | tawkar
# City not found. Skipping...
# Processing Record 44 of Set 5 | bambanglipuro
# Processing Record 45 of Set 5 | sitka
# Processing Record 46 of Set 5 | esperance
# Processing Record 47 of Set 5 | cabra
# Processing Record 48 of Set 5 | tabiauea
# City not found. Skipping...
# Processing Record 49 of Set 5 | krasnoselkup
# Processing Record 0 of Set 6 | mokrous
# Processing Record 1 of Set 6 | qostanay
# Processing Record 2 of Set 6 | barentsburg
# City not found. Skipping...
# Processing Record 3 of Set 6 | talnakh
# Processing Record 4 of Set 6 | saskylakh
# Processing Record 5 of Set 6 | rayon
# Processing Record 6 of Set 6 | neuquen
# Processing Record 7 of Set 6 | saleaula
# City not found. Skipping...
# Processing Record 8 of Set 6 | shu
# Processing Record 9 of Set 6 | zhangye
# Processing Record 10 of Set 6 | eldikan
# City not found. Skipping...
# Processing Record 11 of Set 6 | abapo
# Processing Record 12 of Set 6 | gurgan
# City not found. Skipping...
# Processing Record 13 of Set 6 | kalemie
# Processing Record 14 of Set 6 | bela vista
# Processing Record 15 of Set 6 | krasnoyarka
# Processing Record 16 of Set 6 | raudeberg
# Processing Record 17 of Set 6 | natal
# Processing Record 18 of Set 6 | velikie luki
# City not found. Skipping...
# Processing Record 19 of Set 6 | shelburne
# Processing Record 20 of Set 6 | mount isa
# Processing Record 21 of Set 6 | avera
# Processing Record 22 of Set 6 | khalabat
# Processing Record 23 of Set 6 | coihaique
# Processing Record 24 of Set 6 | ormond beach
# Processing Record 25 of Set 6 | bismarck
# Processing Record 26 of Set 6 | vaitape
# Processing Record 27 of Set 6 | marcona
# City not found. Skipping...
# Processing Record 28 of Set 6 | flinders
# Processing Record 29 of Set 6 | preeceville
# Processing Record 30 of Set 6 | santa maria
# Processing Record 31 of Set 6 | san quintin
# Processing Record 32 of Set 6 | trofors
# Processing Record 33 of Set 6 | faya
# Processing Record 34 of Set 6 | kibray
# Processing Record 35 of Set 6 | imbituba
# Processing Record 36 of Set 6 | ribeira brava
# Processing Record 37 of Set 6 | uong bi
# Processing Record 38 of Set 6 | vaini
# Processing Record 39 of Set 6 | caravelas
# Processing Record 40 of Set 6 | severo-kurilsk
# Processing Record 41 of Set 6 | changde
# Processing Record 42 of Set 6 | bharatpur
# Processing Record 43 of Set 6 | san luis
# Processing Record 44 of Set 6 | asau
# Processing Record 45 of Set 6 | jiddah
# City not found. Skipping...
# Processing Record 46 of Set 6 | pangkalanbuun
# Processing Record 47 of Set 6 | geraldton
# Processing Record 48 of Set 6 | rey bouba
# Processing Record 49 of Set 6 | mahebourg
# Processing Record 0 of Set 7 | ulladulla
# Processing Record 1 of Set 7 | mys shmidta
# City not found. Skipping...
# Processing Record 2 of Set 7 | karaton
# Processing Record 3 of Set 7 | ilhabela
# Processing Record 4 of Set 7 | hvide sande
# Processing Record 5 of Set 7 | laguna
# Processing Record 6 of Set 7 | lascahobas
# Processing Record 7 of Set 7 | labuhan
# Processing Record 8 of Set 7 | mount gambier
# Processing Record 9 of Set 7 
of Set 10 | viligili
# City not found. Skipping...
# Processing Record 1 of Set 10 | vanimo
# Processing Record 2 of Set 10 | dzhankoy
# Processing Record 3 of Set 10 | cap malheureux
# Processing Record 4 of Set 10 | cockburn town
# Processing Record 5 of Set 10 | carauari
# Processing Record 6 of Set 10 | port lincoln
# Processing Record 7 of Set 10 | maceio
# Processing Record 8 of Set 10 | hailey
# Processing Record 9 of Set 10 | muros
# Processing Record 10 of Set 10 | liseleje
# Processing Record 11 of Set 10 | ahipara
# Processing Record 12 of Set 10 | codrington
# Processing Record 13 of Set 10 | srednekolymsk
# Processing Record 14 of Set 10 | hecun
# Processing Record 15 of Set 10 | zhangjiakou
# Processing Record 16 of Set 10 | moron
# Processing Record 17 of Set 10 | kholtoson
# Processing Record 18 of Set 10 | nichinan
# Processing Record 19 of Set 10 | puerto del rosario
# Processing Record 20 of Set 10 | tarakan
# Processing Record 21 of Set 10 | boende
# Processing Record 22 of Set 10 | ballina
# Processing Record 23 of Set 10 | straumen
# Processing Record 24 of Set 10 | silifke
# Processing Record 25 of Set 10 | antofagasta
# Processing Record 26 of Set 10 | bay city
# Processing Record 27 of Set 10 | cody
# Processing Record 28 of Set 10 | birao
# Processing Record 29 of Set 10 | ibra
# Processing Record 30 of Set 10 | zlatoustovsk
# City not found. Skipping...
# Processing Record 31 of Set 10 | bukachacha
# Processing Record 32 of Set 10 | sakakah
# Processing Record 33 of Set 10 | castrillon
# Processing Record 34 of Set 10 | batie
# Processing Record 35 of Set 10 | bar harbor
# Processing Record 36 of Set 10 | cabo san lucas
# Processing Record 37 of Set 10 | salinopolis
# Processing Record 38 of Set 10 | baraya
# Processing Record 39 of Set 10 | palu
# Processing Record 40 of Set 10 | swan hill
# Processing Record 41 of Set 10 | maun
# Processing Record 42 of Set 10 | innisfail
# Processing Record 43 of Set 10 | gboko
# Processing Record 44 of Set 10 | hamilton
# Processing Record 45 of Set 10 | marquette
# Processing Record 46 of Set 10 | rawson
# Processing Record 47 of Set 10 | port macquarie
# Processing Record 48 of Set 10 | lakatoro
# Processing Record 49 of Set 10 | vondrozo
# Processing Record 0 of Set 11 | aitape
# Processing Record 1 of Set 11 | sungaipenuh
# Processing Record 2 of Set 11 | riyadh
# Processing Record 3 of Set 11 | deniliquin
# Processing Record 4 of Set 11 | pangody
# Processing Record 5 of Set 11 | iracoubo
# Processing Record 6 of Set 11 | oytal
# Processing Record 7 of Set 11 | dalbandin
# Processing Record 8 of Set 11 | imperial beach
# Processing Record 9 of Set 11 | kaohsiung
# Processing Record 10 of Set 11 | marystown
# Processing Record 11 of Set 11 | hegra
# Processing Record 12 of Set 11 | sokolo
# Processing Record 13 of Set 11 | arman
# Processing Record 14 of Set 11 | santa paula
# Processing Record 15 of Set 11 | zhezkazgan
# Processing Record 16 of Set 11 | te anau
# Processing Record 17 of Set 11 | marsh harbour
# Processing Record 18 of Set 11 | preobrazheniye
# Processing Record 19 of Set 11 | samusu
# City not found. Skipping...
# Processing Record 20 of Set 11 | bayir
# Processing Record 21 of Set 11 | churapcha
# Processing Record 22 of Set 11 | gat
# Processing Record 23 of Set 11 | zvishavane
# Processing Record 24 of Set 11 | tutoia
# Processing Record 25 of Set 11 | gravdal
# Processing Record 26 of Set 11 | felidhoo
# City not found. Skipping...
# Processing Record 27 of Set 11 | pansemal
# Processing Record 28 of Set 11 | marathon
# Processing Record 29 of Set 11 | sheopur
# Processing Record 30 of Set 11 | huangpu
# Processing Record 31 of Set 11 | bedford
# Processing Record 32 of Set 11 | callaway
# Processing Record 33 of Set 11 | hervey bay
# Processing Record 34 of Set 11 | anadyr
# Processing Record 35 of Set 11 | itanhem
# Processing Record 36 of Set 11 | san policarpo
# Processing Record 37 of Set 11 | itarema
# Processing Record 38 of Set 11 | lubango
# Processing Record 39 of Set 11 | pudozh
# Processing Record 40 of Set 11 | kabare
# Processing Record 41 of Set 11 | cobija
# Processing Record 42 of Set 11 | sri aman
# Processing Record 43 of Set 11 | samarai
# Processing Record 44 of Set 11 | muisne
# Processing Record 45 of Set 11 | vestmanna
# Processing Record 46 of Set 11 | paciran
# Processing Record 47 of Set 11 | komsomolskiy
# Processing Record 48 of Set 11 | petropavlovsk-kamchatskiy
# Processing Record 49 of Set 11 | doha
# Processing Record 0 of Set 12 | faanui
# Processing Record 1 of Set 12 | honiara
# Processing Record 2 of Set 12 | palabuhanratu
# City not found. Skipping...
# Processing Record 3 of Set 12 | popondetta
# Processing Record 4 of Set 12 | valmontone
# Processing Record 5 of Set 12 | ambilobe
# Processing Record 6 of Set 12 | mackay
# Processing Record 7 of Set 12 | teguldet
# Processing Record 8 of Set 12 | chernyshkovskiy
# Processing Record 9 of Set 12 | mildura
# Processing Record 10 of Set 12 | alice springs
# Processing Record 11 of Set 12 | waingapu
# Processing Record 12 of Set 12 | svetlaya
# Processing Record 13 of Set 12 | spokane
# Processing Record 14 of Set 12 | taywarah
# Processing Record 15 of Set 12 | kayerkan
# Processing Record 16 of Set 12 | kamenka
# Processing Record 17 of Set 12 | vardo
# Processing Record 18 of Set 12 | mwandiga
# Processing Record 19 of Set 12 | ancud
# Processing Record 20 of Set 12 | campestre
# Processing Record 21 of Set 12 | lukow
# Processing Record 22 of Set 12 | kabanga
# Processing Record 23 of Set 12 | booue
# Processing Record 24 of Set 12 | bara
# Processing Record 25 of Set 12 | constitucion
# Processing Record 26 of Set 12 | havelock
# Processing Record 27 of Set 12 | kathmandu
# Processing Record 28 of Set 12 | rocha
# Processing Record 29 of Set 12 | varnavino
# Processing Record 30 of Set 12 | dikson
# Processing Record 31 of Set 12 | wanning
# Processing Record 32 of Set 12 | camana
# Processing Record 33 of Set 12 | gilgit
# Processing Record 34 of Set 12 | jennings
# Processing Record 35 of Set 12 | vestmannaeyjar
# Processing Record 36 of Set 12 | matay
# Processing Record 37 of Set 12 | ikwiriri
# Processing Record 38 of Set 12 | ostrov
# Processing Record 39 of Set 12 | auki
# Processing Record 40 of Set 12 | andijon
# Processing Record 41 of Set 12 | mitsamiouli
# Processing Record 42 of Set 12 | bafia
# Processing Record 43 of Set 12 | shieli
# Processing Record 44 of Set 12 | hwange
# Processing Record 45 of Set 12 | save
# Processing Record 46 of Set 12 | dzerzhinsk
# Processing Record 47 of Set 12 | phalombe
# Processing Record 48 of Set 12 | ust-uda
# Processing Record 49 of Set 12 | kimbe
# Processing Record 0 of Set 13 | bila tserkva
# Processing Record 1 of Set 13 | kysyl-syr
# Processing Record 2 of Set 13 | santa
# Processing Record 3 of Set 13 | sar-e pul
# Processing Record 4 of Set 13 | makokou
# Processing Record 5 of Set 13 | neiafu
# Processing Record 6 of Set 13 | byron bay
# Processing Record 7 of Set 13 | conakry
# Processing Record 8 of Set 13 | anar darreh
# City not found. Skipping...
# Processing Record 9 of Set 13 | mongo
# Processing Record 10 of Set 13 | khani
# Processing Record 11 of Set 13 | bulungu
# Processing Record 12 of Set 13 | coshocton
# Processing Record 13 of Set 13 | progreso
# Processing Record 14 of Set 13 | grindavik
# Processing Record 15 of Set 13 | sumbawa
# City not found. Skipping...
# Processing Record 16 of Set 13 | fairbanks
# Processing Record 17 of Set 13 | augusta
# Processing Record 18 of Set 13 | roebourne
# Processing Record 19 of Set 13 | galle
# Processing Record 20 of Set 13 | teguise
# Processing Record 21 of Set 13 | desna
# Processing Record 22 of Set 13 | amboasary
# Processing Record 23 of Set 13 | takoradi
# Processing Record 24 of Set 13 | vredefort
# Processing Record 25 of Set 13 | north bend
# Processing Record 26 of Set 13 | nelson bay
# Processing Record 27 of Set 13 | newport
# Processing Record 28 of Set 13 | cascas
# Processing Record 29 of Set 13 | afyonkarahisar
# Processing Record 30 of Set 13 | reinosa
# Processing Record 31 of Set 13 | viedma
# Processing Record 32 of Set 13 | gherghesti
# Processing Record 33 of Set 13 | eureka
# Processing Record 34 of Set 13 | haftoni
# Processing Record 35 of Set 13 | kemijarvi
# Processing Record 36 of Set 13 | union
# Processing Record 37 of Set 13 | kadykchan
# City not found. Skipping...
# Processing Record 38 of Set 13 | susangerd
# Processing Record 39 of Set 13 | ortakoy
# Processing Record 40 of Set 13 | palasbari
# Processing Record 41 of Set 13 | sulangan
# Processing Record 42 of Set 13 | yaransk
# Processing Record 43 of Set 13 | severo-yeniseyskiy
# Processing Record 44 of Set 13 | anderson
# Processing Record 45 of Set 13 | chapais
# Processing Record 46 of Set 13 | luena
# Processing Record 47 of Set 13 | elat
# Processing Record 48 of Set 13 | iquique
# Processing Record 49 of Set 13 | monroe
# Processing Record 0 of Set 14 | ler
# -----------------------------
# Data Retrieval Complete
# -----------------------------

# %%
# Convert the cities weather data into a Pandas DataFrame
city_data_df = pd.DataFrame(city_data)

# Show Record Count
city_data_df.count()
# Out:
# City          601
# Lat           601
# Lng           601
# Max Temp      601
# Humidity      601
# Cloudiness    601
# Wind Speed    601
# Country       601
# Date          601
# dtype: int64

# %%
# Display sample data
city_data_df.head()
# Out:
#          City      Lat       Lng  Max Temp  Humidity  Cloudiness  Wind Speed  \
# 0     ushuaia -54.8000  -68.3000     13.81        44          40        4.12
# 1   anchorage  61.2181 -149.9003      0.56        65         100        5.66
# 2       kapaa  22.0752 -159.3190     26.72        77          40        5.66
# 3    souillac -20.5167   57.5167     23.21        78          40        2.57
# 4  nikolskoye  59.7035   30.7861      3.94        92         100        4.41
#
#   Country        Date
# 0      AR  1667874945
# 1      US  1667875270
# 2      US  1667875224
# 3      MU  1667875374
# 4      RU  1667875272

# %%
# Export the City_Data into a csv
city_data_df.to_csv("output_data/cities.csv", index_label="City_ID")

# %%
# Read saved data
city_data_df = pd.read_csv("output_data/cities.csv", index_col="City_ID")

# Display sample data
city_data_df.head()
# Out:
#                City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0           ushuaia -54.8000  -68.3000     13.81        44          40
# 1         anchorage  61.2181 -149.9003      0.56        65         100
# 2             kapaa  22.0752 -159.3190     26.72        77          40
# 3          souillac -20.5167   57.5167     23.21        78          40
# 4        nikolskoye  59.7035   30.7861      3.94        92         100
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      AR  1667874945
# 1              5.66      US  1667875270
# 2              5.66      US  1667875224
# 3              2.57      MU  1667875374
# 4              4.41      RU  1667875272

# %% [markdown]
# ### Create the Scatter Plots Requested
#
# #### Latitude Vs. Temperature

# %%
# Build scatter plot for latitude vs. temperature
x_values = city_data_df["Lat"]
y_values = city_data_df["Max Temp"]

# Add Title, Labels, and Gridlines to plot
plt.title("City Max Latitude vs. Temperature (2022-10-27)")
plt.xlabel("Latitude")
plt.ylabel("Max Temperature (C)")
plt.grid()

plt.scatter(x_values, y_values)

# Save the figure
plt.savefig("output_data/Fig1.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Humidity

# %%
# Build the scatter plots for latitude vs. humidity
x_values = city_data_df["Lat"]
y_values = city_data_df["Humidity"]

# Add Title, Labels, and Gridlines to plot
plt.title("City Max Latitude vs. Humidity (2022-10-27)")
plt.xlabel("Latitude")
plt.ylabel("Humidity")
plt.grid()

plt.scatter(x_values, y_values)

# Save the figure
plt.savefig("output_data/Fig2.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude Vs. Cloudiness

# %%
# Build the scatter plots for latitude vs. cloudiness
x_values = city_data_df["Lat"]
y_values = city_data_df["Cloudiness"]

# Add Title, Labels, and Gridlines to plot
plt.title("City Max Latitude vs. Cloudiness (2022-10-27)")
plt.xlabel("Latitude")
plt.ylabel("Cloudiness %")
plt.grid()

plt.scatter(x_values, y_values)

# Save the figure
plt.savefig("output_data/Fig3.png")

# Show plot
plt.show()

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
# Build the scatter plots for latitude vs. wind speed
x_values = city_data_df["Lat"]
y_values = city_data_df["Wind Speed"]

# Add Title, Labels, and Gridlines to plot
plt.title("City Max Latitude vs. Wind Speed (2022-10-27)")
plt.xlabel("Latitude")
plt.ylabel("Wind Speed")
plt.grid()

plt.scatter(x_values, y_values)

# Save the figure
plt.savefig("output_data/Fig4.png")

# Show plot
plt.show()

# %% [markdown]
# ---
#
# ## Requirement 2: Compute Linear Regression for Each Relationship

# %%
# Define a function to create Linear Regression plots

def Linear_Regression_Plots(x,y):
    slope, intercept, r, p, stderr = linregress(x,y)

    plt.plot(x, x * slope + intercept, color="r")

    line_eq = f"y = {slope:.2f}x + {intercept:.2f}"
    plt.legend([line_eq], labelcolor='r')

    # Print r value
    print(f"The r-value is: {r*r}")

# %%
# Create a DataFrame with the Northern Hemisphere data (Latitude >= 0)
northern_hemi_df = city_data_df.loc[(city_data_df["Lat"] >= 0)]

# Display sample data
northern_hemi_df.head()
# Out:
#                 City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 1          anchorage  61.2181 -149.9003      0.56        65         100
# 2              kapaa  22.0752 -159.3190     26.72        77          40
# 4         nikolskoye  59.7035   30.7861      3.94        92         100
# 6        yellowknife  62.4560 -114.3525    -14.69        85          75
# 7             darhan  49.4867  105.9228      1.56        48          61
#
#          Wind Speed Country        Date
# City_ID
# 1              5.66      US  1667875270
# 2              5.66      US  1667875224
# 4              4.41      RU  1667875272
# 6              1.03      CA  1667875694
# 7              1.97      MN  1667875413

# %%
# Create a DataFrame with the Southern Hemisphere data (Latitude < 0)
southern_hemi_df = city_data_df.loc[(city_data_df["Lat"] <= 0)]

# Display sample data
southern_hemi_df.head()
# Out:
#                     City      Lat       Lng  Max Temp  Humidity  Cloudiness  \
# City_ID
# 0                ushuaia -54.8000  -68.3000     13.81        44          40
# 3               souillac -20.5167   57.5167     23.21        78          40
# 5               hermanus -34.4187   19.2345     11.00        86          62
# 11       arraial do cabo -22.9661  -42.0278     19.79        81         100
# 15                atuona  -9.8000 -139.0333     25.07        71          99
#
#          Wind Speed Country        Date
# City_ID
# 0              4.12      AR  1667874945
# 3              2.57      MU  1667875374
# 5              2.86      ZA  1667875412
# 11             2.47      BR  1667875695
# 15             6.72      PF  1667875696

# %% [markdown]
# ###  Temperature vs. Latitude Linear Regression Plot

# %%
# Linear regression on Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Max Temp"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.7671037847189646

# %%
# Linear regression on Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Max Temp"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Max Temp")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.23060495697201255

# %% [markdown]
# **Discussion about the linear relationship:** Within the Nothern the data is showing a strong relationshiop between and Temperature. Generally, the higher the the lower the max temperature.
#
# The Southern relationship is opposite of Northern's, however, it's not as consistent given the r-value is .23 vs Northern's .767.

# %% [markdown]
# ### Humidity vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Humidity"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.11493320025786374

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Humidity"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Humidity")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.0760072046147896

# %% [markdown]
# **Discussion about the linear relationship:** The linear moving backward line between (how north or south and Humidity shows no relationship on Northern nor Southern.

# %% [markdown]
# ### Cloudiness vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Cloudiness"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.06331192536121608

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Cloudiness"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Cloudiness")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.0719164941041697

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression line between Latitude and Cloudiness shows no relationship on Northern nor Southern Hemisphere.

# %% [markdown]
# ### Wind Speed vs. Latitude Linear Regression Plot

# %%
# Northern Hemisphere
x_values = northern_hemi_df["Lat"]
y_values = northern_hemi_df["Wind Speed"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Wind Speed")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.05742177738841386

# %%
# Southern Hemisphere
x_values = southern_hemi_df["Lat"]
y_values = southern_hemi_df["Wind Speed"]

Linear_Regression_Plots(x_values, y_values)

plt.xlabel("Latitude")
plt.ylabel("Wind SPeed")

plt.scatter(x_values, y_values)

plt.show()
# Out:
# The r-value is: 0.1085588824256235

# %% [markdown]
# **Discussion about the linear relationship:** The linear regression line between Latitude and Wind Speed shows no relationship on Northern nor Southern Hemisphere.
